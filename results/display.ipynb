# %%
import numpy as np
from pathlib import Path
from matplotlib import pyplot as plot

# %%
dir = 'nocorr0.0004'

for filename in Path(dir).glob('*.npy'):
    data = np.load(filename).squeeze()
    print(filename, data.shape)
    
    plot.imshow(data, cmap='turbo')
    plot.show()
    
    break
# Out:
# nocorr0.0004/00000000.npy (384, 512)

# %%
data.min(), data.max()
# Out:
# (3.344427, 27.48127)
